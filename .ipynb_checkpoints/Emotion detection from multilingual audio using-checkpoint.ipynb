# %% [markdown]
# # RAVDESS (Ryerson Audio-Visual Database of Emotional Speech and Song)

# %% [markdown]
# Il Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS) contiene 7.356 file (dimensione totale: 24,8 GB). Il database contiene 24 attori professionisti (12 femmine, 12 maschi), che vocalizzano due affermazioni lessicalmente abbinate con un accento nordamericano neutro. Il discorso(Speech) include espressioni calme, felici, tristi, arrabbiate, paurose, sorprese e disgustate, e il canto(Song) contiene emozioni calme, felici, tristi, arrabbiate e paurose. Ogni espressione è prodotta a due livelli di intensità emotiva (normale, forte), con un'espressione neutra aggiuntiva. Tutte le condizioni sono disponibili in tre formati di modalità: solo audio (16 bit, 48kHz .wav), audio-video (720p H.264, AAC 48kHz, .mp4) e solo video (senza audio). Nota, non ci sono file di canzoni per Actor_18.

# %% [markdown]
# # Import moduli

# %%
#!pip install librosa
#se già installato de-commenta il comando precedente
import librosa
import librosa.display

# %%
import os
from glob import glob
import numpy as np
import pandas as pd
import IPython.display as ipd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Navigazione adio
# data

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aleza\\Desktop\\TesiAZ'

# %%
path = os.getcwd()
file_name = "Audio_Speech_Actors_01-24"
new_path = os.path.join(path, file_name)
os.chdir(new_path)

# %%
os.listdir()
# Out:
# ['Actor_01',
#  'Actor_02',
#  'Actor_03',
#  'Actor_04',
#  'Actor_05',
#  'Actor_06',
#  'Actor_07',
#  'Actor_08',
#  'Actor_09',
#  'Actor_10',
#  'Actor_11',
#  'Actor_12',
#  'Actor_13',
#  'Actor_14',
#  'Actor_15',
#  'Actor_16',
#  'Actor_17',
#  'Actor_18',
#  'Actor_19',
#  'Actor_20',
#  'Actor_21',
#  'Actor_22',
#  'Actor_23',
#  'Actor_24']

# %%
path = os.getcwd()
file_name = "Actor_01"
new_path2 = os.path.join(path, file_name)

# %%
os.listdir(new_path2)[0]
# Out:
# '03-01-01-01-01-01-01.wav'

# %%
new_path3 = os.path.join(new_path2, os.listdir(new_path2)[0])

# %%
print(new_path, '\n' + new_path2, '\n' + new_path3)
# Out:
# C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Actors_01-24
# C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Actors_01-24\Actor_01
# C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Actors_01-24\Actor_01\03-01-01-01-01-01-01.wav

# %% [markdown]
# ### Vogliamo convertire il suono in un array numpy

# %%
y, sr = librosa.load(new_path3)
ps = librosa.feature.melspectrogram(y=y, sr=sr)
ps.shape
# Out:
# (128, 143)

# %%
librosa.display.specshow(ps, y_axis='mel', x_axis='time')

# %%
librosa.display.waveshow(ps, sr=sr)

# %% [markdown]
# Usando le Librerie del sistema operativo per navigare in tutte le cartelle e i file in un percorso di directory, in questo caso ('Desktop/tesi/Audio_Speech_Actors_01-24') dopo questo si tratta solo di stampare i dati...<br> Fondamentalmente mostra che i dati e i file disponibili per essere utilizzati nel notebook

# %%
def file_list(directory):
    dirs = os.listdir(directory)
    for dir in dirs:
        print(dir)
        path = os.path.join(directory, dir)
        files = os.listdir(path)
        print(files)

# %%
file_list(os.getcwd())
# Out:
# Actor_01
# ...

# %%
audio_files = glob('..\\Audio_Speech_Actors_01-24\\*\\*.wav')

# %%
audio_files[:10]
# Out:
# ['..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-01-01-01-01-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-01-01-01-02-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-01-01-02-01-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-01-01-02-02-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-02-01-01-01-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-02-01-01-02-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-02-01-02-01-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-02-01-02-02-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-02-02-01-01-01.wav',
#  '..\\Audio_Speech_Actors_01-24\\Actor_01\\03-01-02-02-01-02-01.wav']

# %%
ipd.Audio(audio_files[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## Convenzione di denominazione dei file
# Il file vocale (Audio_Speech_Actors_01-24.zip, 215 MB) contiene 1440 file: 60 prove per attore x 24 attori = 1440.<br>
# Ciascuno dei file RAVDESS ha un nome file univoco. Il nome del file è costituito da un identificatore numerico in 7 parti (ad esempio, 02-01-06-01-02-01-12.mp4).
#
# Filename identifiers:
#
# - Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
# - Vocal channel (01 = speech, 02 = song).
# - Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
# - Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
# - Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
# - Repetition (01 = 1st repetition, 02 = 2nd repetition).
# - Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).

# %% [markdown]
# # Creazione file csv
# Prima di creare il file csv, dobbiamo cambiare il cirectory con quello che punta al set di dati del padre di ravdess (Audio_Speech_Actors_01-24).

# %%
from os.path import dirname
ravdess = new_path # or os.getcwd()
path = dirname(ravdess)
os.chdir(path)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aleza\\Desktop\\TesiAZ'

# %%
dirs = os.listdir(ravdess)
file_emotion = []
file_emotional_intensity = []
file_statement = []
file_path = []
for dir in dirs:
    actor = os.listdir(ravdess + '/' + dir)
    for audio in actor:
        part = audio.split('.')[0]
        part = part.split('-')
        file_emotion.append(int(part[2]))
        file_emotional_intensity.append(int(part[3]))
        file_statement.append(int(part[4]))
        file_path.append(ravdess + '/' + dir + '/' + audio)

# %% [markdown]
# ## Creazione di un dataframe pandas con le emozioni e il percorso audio

# %%
emotion_df = pd.DataFrame(file_emotion, columns=['Emotions'])
emotional_intensity_df = pd.DataFrame(file_emotional_intensity, columns=['Emotional_intensity'])
statement_df = pd.DataFrame(file_statement, columns=['Statement'])
path_df = pd.DataFrame(file_path, columns=['Path'])
ravdess_df = pd.concat([path_df, emotion_df, emotional_intensity_df, statement_df], axis=1)

# %%
ravdess_df.Emotions.replace({1:'neutral', 2:'calm', 3:'happy', 4:'sad', 5:'angry', 6:'fearful', 7:'disgust', 8:'surprised'}, inplace=True)
ravdess_df.Emotional_intensity.replace({1:'normal', 2:'strong'}, inplace=True)
ravdess_df.Statement.replace({1:'Kids are talking by the door', 2:'Dogs are sitting by the door'}, inplace=True)
ravdess_df
# Out:
#                                                    Path   Emotions  \
# 0     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 1     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 2     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 3     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 4     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...       calm
# ...                                                 ...        ...
# 1435  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1436  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1437  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1438  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1439  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
#
#      Emotional_intensity                     Statement
# 0                 normal  Kids are talking by the door
# ...

# %% [markdown]
# # Estrazione feature con librosa

# %% [markdown]
# - __chroma_stft(*[, y, sr, S, norm, n_fft, ...])__ Calcola un cromagramma da una forma d'onda o uno spettrogramma di potenza.
#
# - __melspectrogram(*[, y, sr, S, n_fft, ...])__ Calcola uno spettrogramma in scala mel.
#
# - __mfcc(*[, y, sr, S, n_mfcc, dct_type, norm, ...])__ Coefficienti cepstrali di frequenza Mel (MFCC)
#
# - __spectral_contrast(*[, y, sr, S, n_fft, ...])__ Calcola il contrasto spettrale
#
# - __tonnetz(*[, y, sr, chroma])__ Calcola le caratteristiche del centroide tonale (tonnetz)

# %%
chroma_stft = []
melspectrogram = []
mfcc = []
spectral_contrast = []
tonnetz = []


for audio_file in ravdess_df["Path"]:
    data, sample_rate = librosa.load(audio_file)
    
    # Chroma_stft
    stft = np.abs(librosa.stft(data))
    chroma_stft.append(np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0))

    # MelSpectogram
    melspectrogram.append(np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0))
    
    # MFCC
    mfcc.append(np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0))
    
    # Spectral_contrast
    spectral_contrast.append(np.mean(librosa.feature.spectral_contrast(y=data, sr=sample_rate).T, axis=0))

    # Tonnetz
    tonnetz.append(np.mean(librosa.feature.tonnetz(y=data).T, axis=0))
# Out:
# C:\Users\aleza\anaconda3\lib\site-packages\librosa\util\decorators.py:88: UserWarning: n_fft=1024 is too small for input signal of length=1012
#   return f(*args, **kwargs)

# %% [markdown]
# Creo i dataframe: chroma 12, mel 128, mfcc 20, contrast 7, tonnetz 6 colonne.
#
# Il metodo rename di default non cambia il valore delle colonne del dataframe (inplace vale false di default) ma restituisce un nuovo dataframe con le colonne cambiate. Devi quindi assegnarlo alla variabile

# %%
chroma_df = pd.DataFrame(chroma_stft)
chroma_df.rename(columns=lambda i: 'Chroma_' + str(i+1), inplace=True)

# %%
mel_df = pd.DataFrame(melspectrogram)
mel_df.rename(columns=lambda i: 'MelSpectrogram_' + str(i+1), inplace=True)

# %%
mfcc_df = pd.DataFrame(mfcc)
mfcc_df.rename(columns=lambda i: 'MFCC_' + str(i+1), inplace=True)

# %%
contrast_df = pd.DataFrame(spectral_contrast)
contrast_df.rename(columns=lambda i: 'SpectralContrast_' + str(i+1), inplace=True)

# %%
tonnetz_df = pd.DataFrame(tonnetz)
tonnetz_df.rename(columns=lambda i: 'Tonnetz_' + str(i+1), inplace=True)

# %%
features_df = pd.concat([chroma_df, mel_df, mfcc_df, contrast_df, tonnetz_df], axis=1)
features_df
# Out:
#       Chroma_1  Chroma_2  Chroma_3  Chroma_4  Chroma_5  Chroma_6  Chroma_7  \
# 0     0.758700  0.800079  0.787812  0.765054  0.709206  0.683322  0.691785
# 1     0.750273  0.784383  0.756965  0.696240  0.693709  0.674186  0.693022
# 2     0.774295  0.801573  0.796509  0.787654  0.728228  0.677872  0.681009
# 3     0.779107  0.755077  0.747366  0.743538  0.722850  0.710327  0.703550
# 4     0.698006  0.760674  0.788748  0.732748  0.676882  0.686023  0.674742
# ...        ...       ...       ...       ...       ...       ...       ...
# 1435  0.627197  0.556213  0.542518  0.548569  0.530505  0.541727  0.590350
# 1436  0.706613  0.714364  0.660312  0.624816  0.557339  0.514953  0.538145
# 1437  0.655388  0.660653  0.591902  0.567328  0.518754  0.527598  0.543928
# 1438  0.639784  0.633800  0.618443  0.583396  0.554781  0.593419  0.598049
# 1439  0.697430  0.636318  0.615314  0.577386  0.544395  0.577520  0.592597
#
#       Chroma_8  Chroma_9  Chroma_10  ...  SpectralContrast_4  \
# ...

# %% [markdown]
# # Creazione file csv

# %% [markdown]
# Il database che viene a crearsi deve avere come righe gli attori e come colonne: emozione, intensità, statement, percorso, per ogni feature una colonna con i valori estratti per quel file audio dalla rispettiva feature

# %%
dataset = pd.concat([ravdess_df, features_df], axis=1) #unisco i due dataframe
dataset.to_csv("dataset.csv", index=False)
dataset
# Out:
#                                                    Path   Emotions  \
# 0     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 1     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 2     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 3     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...    neutral
# 4     C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...       calm
# ...                                                 ...        ...
# 1435  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1436  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1437  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1438  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
# 1439  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  surprised
#
#      Emotional_intensity                     Statement  Chroma_1  Chroma_2  \
# 0                 normal  Kids are talking by the door  0.758700  0.800079
# ...

# %%
dataset = pd.read_csv('dataset.csv', index_col=False)

# %%
dataset.head(6)
# Out:
#                                                 Path Emotions  \
# 0  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 1  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 2  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 3  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 4  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...     calm
# 5  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...     calm
#
#   Emotional_intensity                     Statement  Chroma_1  Chroma_2  \
# 0              normal  Kids are talking by the door  0.758700  0.800079
# 1              normal  Kids are talking by the door  0.750273  0.784383
# 2              normal  Dogs are sitting by the door  0.774295  0.801573
# 3              normal  Dogs are sitting by the door  0.779107  0.755077
# 4              normal  Kids are talking by the door  0.698006  0.760674
# 5              normal  Kids are talking by the door  0.727278  0.760926
#
# ...

# %% [markdown]
# # Analisi variabili del datset
# - **Path**: il percorso univoco al file audio (usato per distinguere tutti i file audio);
# - **Emotions**: emozione usata;
# - **Emotional_intensity**: enfasi
# - **Statement**: frase pronunciata;
# - **Chroma_x**: funzionalità potenti per l'analisi della musica, infatti le caratteristiche cromatiche sono molto autentiche per catturare le caratteristiche armoniche e melodiche della musica e dello strumento;
# - **MelSpectrogram_x**: input dello spettrogramma mappato direttamente sulla funzione di base Mel, questa rappresentazione dello spettrogramma aumenta la chiarezza uditiva del sistema;
# - **MFCC_x**: è la caratteristica spettrale più utilizzata nel riconoscimento delle emozioni vocali, è una caratteristica vantaggiosa per raccogliere benefici dall'audio grezzo. Funziona anche in modo molto efficace nel rumore; il sistema uditivo umano non è lineare; pertanto, MFCC utilizza la scala Mel;
# - **SpectralContrast_x**: viene stimata l'energia media di un suono e il valore di contrasto elevato è evidente e il valore di contrasto basso corrisponde al rumore a banda larga;
# - **Tonnetz_x**: le caratteristiche di Tonnetz funzionano allo stesso modo come il cromatogramma, è anche correlato all'armonia e alla classe del tono.

# %% [markdown]
# Come si può notare anche dalla cella qui sotto, il numero di variabili è 177 mentre le istanze totali sono 1440.

# %%
dataset.shape
# Out:
# (1440, 177)

# %%
target = "Emotions"

# %%
dataset["Emotions"].value_counts()
# Out:
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: Emotions, dtype: int64

# %%
dataset["Emotions"].value_counts().plot.pie(autopct="%.2f%%");

# %% [markdown]
# Analisi dei dati con distribuzioni, medie, stddev, percentili, numero valori distinti delle feature.

# %%
dataset.iloc[:, :].describe()
# Out:
#           Chroma_1     Chroma_2     Chroma_3     Chroma_4     Chroma_5  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean      0.653244     0.655611     0.657969     0.645570     0.617216
# std       0.076868     0.086938     0.090251     0.091643     0.089298
# min       0.367825     0.322613     0.315760     0.329007     0.344647
# 25%       0.603348     0.597126     0.594429     0.580775     0.552444
# 50%       0.661144     0.661716     0.667607     0.660002     0.636207
# 75%       0.709583     0.724050     0.726551     0.714091     0.683862
# max       0.840786     0.867350     0.858982     0.858208     0.821597
#
#           Chroma_6     Chroma_7     Chroma_8     Chroma_9    Chroma_10  ...  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000  ...
# mean      0.623934     0.633670     0.656429     0.669104     0.666066  ...
# std       0.083622     0.077928     0.081345     0.079156     0.077403  ...
# ...

# %%
dataset.pivot_table(index="Path", columns="Emotions", values="MFCC_1").plot.hist(bins=40, stacked=True, figsize=(12, 6));

# %%
dataset.pivot_table(index="Path", columns="Emotional_intensity", values="MFCC_1").plot.hist(bins=40, stacked=True, figsize=(12, 6));

# %%
not_features = ["Path", "Emotional_intensity", "Statement"]
features_data = dataset.drop(columns=not_features)
features_data
# Out:
#        Emotions  Chroma_1  Chroma_2  Chroma_3  Chroma_4  Chroma_5  Chroma_6  \
# 0       neutral  0.758700  0.800079  0.787812  0.765054  0.709206  0.683323
# 1       neutral  0.750273  0.784383  0.756965  0.696240  0.693709  0.674186
# 2       neutral  0.774295  0.801573  0.796509  0.787654  0.728228  0.677872
# 3       neutral  0.779107  0.755077  0.747366  0.743538  0.722850  0.710327
# 4          calm  0.698006  0.760674  0.788748  0.732748  0.676882  0.686023
# ...         ...       ...       ...       ...       ...       ...       ...
# 1435  surprised  0.627197  0.556213  0.542518  0.548569  0.530505  0.541727
# 1436  surprised  0.706613  0.714364  0.660312  0.624816  0.557339  0.514953
# 1437  surprised  0.655388  0.660653  0.591902  0.567328  0.518754  0.527598
# 1438  surprised  0.639784  0.633800  0.618443  0.583396  0.554781  0.593419
# 1439  surprised  0.697430  0.636318  0.615314  0.577386  0.544395  0.577520
#
# ...

# %%
for col in range(len(features_data.columns.to_list())-1):
    separator = "----------------------------------\n"
    print(separator + f'{features_data.columns.to_list()[col].upper()}\n')
    print(features_data.iloc[:, col].value_counts())
# Out:
# ----------------------------------
# EMOTIONS
#
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: Emotions, dtype: int64
# ----------------------------------
# CHROMA_1
#
# 0.786983    2
# 0.758700    1
# 0.732142    1
# 0.749967    1
# 0.747811    1
#            ..
# 0.628574    1
# 0.633678    1
# 0.646831    1
# 0.646644    1
# 0.697430    1
# Name: Chroma_1, Length: 1439, dtype: int64
# ----------------------------------
# CHROMA_2
#
# 0.764198    2
# 0.748248    2
# 0.800079    1
# 0.656958    1
# 0.764956    1
#            ..
# 0.647770    1
# 0.642908    1
# 0.650008    1
# 0.624191    1
# 0.636318    1
# Name: Chroma_2, Length: 1438, dtype: int64
# ----------------------------------
# CHROMA_3
#
# 0.669064    2
# 0.787812    1
# 0.758433    1
# 0.741710    1
# 0.768612    1
#            ..
# 0.638299    1
# 0.675856    1
# 0.634240    1
# 0.607621    1
# ...

# %% [markdown]
# ## Elaborazione dei dati

# %% [markdown]
# In questa fase seguirà un'analisi più approfondita dei dati: standardizzazione, eliminazione feature meno rilevanti con regolarizzazione L1, discretizzazione e binarizzazione delle feature, analisi tramite modelli.
#
# Modello di classificazione lineare con due feature
# Un classificatore a due classi lineare è definito da un iperpiano che separa lo spazio delle variabili in due semispazi
# la classe prevista per un'osservazione (un punto) dipende dal semispazio in cui si trova
# Se consideriamo uno spazio di due variabili (un piano), questo significa in pratica tracciare una retta che separi una classe dall'altra.
#
# Selezioniamo i dati su cui lavorare:
# - la variabile y da predire è la classe: Emotins;
# - le variabili X sono: le varie features (Chroma, MelSpectrogram, MFCC, Spectral_contrast, Tonnetz);

# %%
features_data.shape
# Out:
# (1440, 174)

# %%
y = features_data["Emotions"]
X2d = features_data[dataset.columns[4:]]

# %% [markdown]
# - Suddividiamo i dati in un training set e in un validation set con la funzione train_test_split

# %%
from sklearn.model_selection import train_test_split

X2d_train, X2d_val, y_train, y_val = train_test_split(
    X2d, y,           # dati da suddividere
    test_size=0.2,    # proporzione: 80% training, 20% validation
    random_state=42   # seed per la riproducibilità
)

# %%
from sklearn.linear_model import Perceptron
model = Perceptron(random_state=42)

# %% [markdown]
# - Applichiamo un filtro di standardizzazione alle features in quanto esse hanno scale molto diverse.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X2dn_train = scaler.fit_transform(X2d_train)
X2dn_val = scaler.transform(X2d_val)

# %% [markdown]
# - Creiamo quindi un semplice modello di classificazione, il Perceptron:

# %%
from sklearn.linear_model import Perceptron
model = Perceptron(random_state=42)

# %% [markdown]
# - Addestriamo il modello sul training set standardizzato.

# %%
model.fit(X2dn_train, y_train);

# %% [markdown]
# - Proviamo a calcolare lo score del modello:

# %%
model.score(X2dn_val, y_val)
# Out:
# 0.4166666666666667

# %% [markdown]
# - L'accuratezza è al 42% circa, ma siccome le classi sono sbilanciate quella utilizzata potrebbe non essere una misura d'errore adatta, meglio provarne anche di altre.
# - Calcoliamo quindi una confusion_matrix o matrice di confusione per osservare quante classificazioni sono andate a buon fine per entrambe le classi:

# %%
from sklearn.metrics import confusion_matrix
y_pred = model.predict(X2dn_val)
cm = confusion_matrix(y_val, y_pred)

# %%
pd.DataFrame(cm, index=model.classes_, columns=model.classes_)
# Out:
#            angry  calm  disgust  fearful  happy  neutral  sad  surprised
# angry         25     0        9        3      3        0    0          2
# calm           1    26        5        4      2        4    2          0
# disgust        3     2       19        1      4        1    0          2
# fearful        0     0        1       16      7        1    4          3
# happy          4     2        2        7     14        0    1          4
# neutral        0     5        2        3      2        5    2          1
# sad            1     7        4       12      6        5    2          2
# surprised      3     1       12        7      6        2    1         13

# %%
from sklearn.metrics import f1_score

# %%
f1_score(y_val, y_pred, average=None)
# Out:
# array([0.63291139, 0.59770115, 0.44186047, 0.37647059, 0.35897436,
#        0.26315789, 0.07843137, 0.36111111])

# %%
f1_score(y_val, y_pred, average="macro")
# Out:
# 0.38882729156915696

# %% [markdown]
# # Modello di classificazione lineare con tutte le feature e pre-processing dei dati
# Non soddisfatti dai risultati ottenuti abbiamo deciso di utiizzare nuovamente il Perceptron, questa volta inserendo più features all'interno della variabile X2d; verificheremo l'accuratezza del modello a livello numerico.
#
# Procediamo preparando i dati per il nostro modello:
#
# Per prima cosa eliminiamo tutte le colonne che non ci servono(not_features) e tutte le istanze, o righe, dove vi è almeno un valore NaN.

# %%
dataset_relevant_features = dataset.drop(columns = "Path")

# %%
dataset_relevant_features.shape
# Out:
# (1440, 176)

# %%
dataset_relevant_features.dropna(inplace=True)

# %%
dataset_relevant_features.shape
# Out:
# (1440, 176)

# %% [markdown]
# - Non ci sono valori NaN

# %% [markdown]
# - Risultano due feature con dati categorici: Emotional_intensity, Statement.
# - In virtù di ciò è ora importante differenziare in due matrici le variabili numeriche da quelle categoriche, in modo da poter pre-processare correttamente entrambi i tipi.
# - In questo caso può essere fatto attraverso un ColumnTransformer.
# - Prima però definiamo la variabile target la quale ora rappresenta la colonna delle Emotions, che viene poi eliminata da dataset_relevant_features, ossia il DataFrame ottenuto al passo precedente.

# %%
target = dataset_relevant_features["Emotions"]
dataset_relevant_features.drop(columns=["Emotions"], inplace=True)

# %% [markdown]
# - Con lo stesso metodo salviamo in categorical_features, che è un DataFrame, i dati relativi a Emotional_intenity e Statement.
# - Questo per ricavare poi due liste con le intestazioni di tutte le colonne categoriche e numeriche.

# %%
categorical_features = dataset_relevant_features[["Emotional_intensity", "Statement"]]
dataset_relevant_features.drop(columns=["Emotional_intensity", "Statement"], inplace=True)

# %%
numeric_values = dataset_relevant_features.columns.to_list()
categorical_values = categorical_features.columns.to_list()

# %%
numeric_values
# Out:
# ['Chroma_1',
#  'Chroma_2',
#  'Chroma_3',
#  'Chroma_4',
#  'Chroma_5',
#  'Chroma_6',
#  'Chroma_7',
#  'Chroma_8',
#  'Chroma_9',
#  'Chroma_10',
#  'Chroma_11',
#  'Chroma_12',
#  'MelSpectrogram_1',
#  'MelSpectrogram_2',
#  'MelSpectrogram_3',
#  'MelSpectrogram_4',
#  'MelSpectrogram_5',
#  'MelSpectrogram_6',
#  'MelSpectrogram_7',
#  'MelSpectrogram_8',
#  'MelSpectrogram_9',
#  'MelSpectrogram_10',
#  'MelSpectrogram_11',
#  'MelSpectrogram_12',
#  'MelSpectrogram_13',
#  'MelSpectrogram_14',
#  'MelSpectrogram_15',
#  'MelSpectrogram_16',
#  'MelSpectrogram_17',
#  'MelSpectrogram_18',
#  'MelSpectrogram_19',
#  'MelSpectrogram_20',
#  'MelSpectrogram_21',
#  'MelSpectrogram_22',
#  'MelSpectrogram_23',
#  'MelSpectrogram_24',
#  'MelSpectrogram_25',
#  'MelSpectrogram_26',
#  'MelSpectrogram_27',
#  'MelSpectrogram_28',
#  'MelSpectrogram_29',
#  'MelSpectrogram_30',
#  'MelSpectrogram_31',
#  'MelSpectrogram_32',
#  'MelSpectrogram_33',
#  'MelSpectrogram_34',
# ...

# %%
categorical_values
# Out:
# ['Emotional_intensity', 'Statement']

# %% [markdown]
# Ora riassembliamo le due matrici ottenendo X2d, una versione di dataset_relevant_features ma senza la colonna Emotions, inoltre la colonna Emotional_intensity è la penultima piuttosto che prima.

# %%
X2d = pd.DataFrame(
    np.c_[dataset_relevant_features, categorical_features], 
    index=dataset_relevant_features.index, 
    columns=numeric_values + categorical_values
)

# %%
X = X2d
X
# Out:
#       Chroma_1  Chroma_2  Chroma_3  Chroma_4  Chroma_5  Chroma_6  Chroma_7  \
# 0       0.7587  0.800079  0.787812  0.765054  0.709206  0.683323  0.691785
# 1     0.750273  0.784383  0.756965   0.69624  0.693709  0.674186  0.693022
# 2     0.774295  0.801573  0.796509  0.787654  0.728228  0.677872  0.681009
# 3     0.779107  0.755077  0.747366  0.743538   0.72285  0.710327   0.70355
# 4     0.698006  0.760674  0.788748  0.732748  0.676882  0.686023  0.674742
# ...        ...       ...       ...       ...       ...       ...       ...
# 1435  0.627197  0.556213  0.542518  0.548569  0.530505  0.541727   0.59035
# 1436  0.706613  0.714364  0.660312  0.624816  0.557339  0.514953  0.538145
# 1437  0.655388  0.660653  0.591902  0.567328  0.518754  0.527598  0.543928
# 1438  0.639784    0.6338  0.618443  0.583396  0.554781  0.593419  0.598049
# 1439   0.69743  0.636318  0.615314  0.577386  0.544395   0.57752  0.592597
#
# ...

# %% [markdown]
# # ----------------------------------- Codice da corregere ---------------------------------------------

# %% [markdown]
# # Pre-processing dei dati numerici e categorici
# E' giunto ora il momento di attuare delle trasformazioni sui dati:
# - Utilizziamo, come già anticipato, un ColumnTransformer per gestire sia variabili numeriche che categoriche rispettivamente attraverso uno StandardScaler, che attua una standardizzazione dei dati, ed un OneHotEncoder, che trasforma le variabili categoriche in numeriche.
# - Abbiamo scelto di usare il OneHotEncoder fuori da una Pipeline e su tutti i dati perchè nel validation set sono presenti istanze con valori non noti tramite il training set.

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.pipeline import Pipeline

# %%
transformer = ColumnTransformer([
    ("numeric", StandardScaler(), numeric_values),
    ("categorical", OneHotEncoder(drop=None, sparse_output=False), categorical_values)
])

# %%
X2d_processed = transformer.fit_transform(X2d)

# %%
features_after_processing = X2d.columns[:-2].to_list() + transformer.named_transformers_["categorical"].get_feature_names(["Emotional_intensity", "Statement"]).tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16388/2835616987.py in <module>
# ----> 1 features_after_processing = X2d.columns[:-2].to_list() + transformer.named_transformers_["categorical"].get_feature_names(["Emotional_intensity", "Statement"]).tolist()
#
# AttributeError: 'OneHotEncoder' object has no attribute 'get_feature_names'

# %%
pd.DataFrame(
    X2d_processed,
    index=X2d.index,
    columns=features_after_processing
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16388/3333387290.py in <module>
#       2     X2d_processed,
#       3     index=X2d.index,
# ----> 4     columns=features_after_processing
#       5 )
#
# NameError: name 'features_after_processing' is not defined

# %%
y_train.value_counts()
# Out:
# fearful      160
# disgust      160
# happy        158
# sad          153
# angry        150
# calm         148
# surprised    147
# neutral       76
# Name: Emotions, dtype: int64

# %%
y = target

# %%
X2d_train, X2d_val, y_train, y_val = train_test_split(
    X2d_processed, y,           # dati da suddividere
    test_size=0.2,    # proporzione: 80% training, 20% validation
    random_state=42   # seed per la riproducibilità
)

# %% [markdown]
# **Random Forest**: algoritmo di tipo bagging, dove vengono creati numerosi alberi decisionali in parallelo, ognuno da un sottoinsieme del dataset di training in generale non disgiunto dagli altri.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(5, shuffle=True, random_state=42)

# %%
from sklearn.metrics import make_scorer
gs = GridSearchCV(model, grid, cv=skf, scoring=make_scorer(f1_score, average="macro"), n_jobs=-1)

# %%
rfm = RandomForestClassifier(max_samples=0.9, n_estimators=200, max_depth=None, n_jobs=-1, random_state=42)

# %%
grid = {
    "max_samples": [0.3, 0.6, 0.9],
    "n_estimators": [200, 400, 600]
}

# %%
gs = GridSearchCV(rfm, grid, cv=skf, scoring=make_scorer(f1_score, average="macro"))

# %%
gs.fit(X2d_train, y_train);
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16388/2717007545.py in <module>
# ----> 1 gs.fit(X2d_train, y_train);
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     873                 return results
#     874
# --> 875             self._run_search(evaluate_candidates)
#     876
#     877             # multimetric is determined here because in the case of a callable
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in _run_search(self, evaluate_candidates)
#    1387     def _run_search(self, evaluate_candidates):
#    1388         """Search all candidates in param_grid"""
# -> 1389         evaluate_candidates(ParameterGrid(self.param_grid))
#    1390
#    1391
#
# ...

# %%
gs.best_params_

# %%
gscv_results = pd.DataFrame(gs.cv_results_).sort_values("rank_test_score")
gscv_results.head(10)

# %%
model = gs.best_estimator_

# %%
f1_score(y_val_balanced, model.predict(X2d_val_balanced), average="macro")

# %%
f1_score(y_val_balanced, model.predict(X2d_val_balanced), average=None)

# %% [markdown]
# # ----------------------------------- link utili + materiale ----------------------------------------------
# - https://librosa.org/doc/latest/index.html
# - https://librosa.org/doc/latest/feature.html
# - https://librosa.org/doc/latest/tutorial.html
# - https://www.kaggle.com/code/robikscube/working-with-audio-in-python/notebook
# - https://www.youtube.com/watch?v=eHJrZa2LtKw&t=221s
# - https://stackoverflow.com/questions/68645918/how-to-export-data-frame-in-jupyter-as-a-csv-file Quando ho il df per salvarlo come csv
# - https://pysoundfile.readthedocs.io/en/latest/

# %% [markdown]
# Primo, al posto di fare direttamnente chroma_stft.append(librosa.feature.chroma_stft(y=y, sr=sr)), calcoli la media. Ad esempio, per chrome_stft:<br>
# stft = np.abs(librosa.stft(data))<br>
# chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)<br>
#
# In questo modo riduciamo la grandezza dell'input. Funzione per l'estrazione dell'input.
#
#     def extract_features(data):
#         # ZCR
#         result = np.array([])
#         zcr = np.mean(librosa.feature.zero_crossing_rate(y=data).T, axis=0)
#         result=np.hstack((result, zcr)) # stacking horizontally
#
#       # Chroma_stft
#         stft = np.abs(librosa.stft(data))
#         chroma_stft = np.mean(librosa.feature.chroma_stft(S=stft, sr=sample_rate).T, axis=0)
#         result = np.hstack((result, chroma_stft)) # stacking horizontally
#
#         # MFCC
#         mfcc = np.mean(librosa.feature.mfcc(y=data, sr=sample_rate).T, axis=0)
#         result = np.hstack((result, mfcc)) # stacking horizontally
#
#         # Root Mean Square Value
#         rms = np.mean(librosa.feature.rms(y=data).T, axis=0)
#         result = np.hstack((result, rms)) # stacking horizontally
#
#         # MelSpectogram
#         mel = np.mean(librosa.feature.melspectrogram(y=data, sr=sample_rate).T, axis=0)
#         result = np.hstack((result, mel)) # stacking horizontally
#
#         #spectral centroid
#         spec_cent=np.mean(librosa.feature.spectral_centroid(y=data, sr=sample_rate).T, axis=0)
#         result = np.hstack((result, spec_cent)) # stacking horizontally
#
#         return result
#
# Successivamente, nel dataframe non deve avere degli array come valori ma al massimo questi vanno scomposti in colonne diverse.
#
# Es: Colonna: valore<br>
# Chroma: [1,2,3,5,6]
#
# Deve diventare:<br>
# Chroma_1: 1<br>
# Chroma_2: 2<br>
# Chroma_3: 3<br>
# Chroma_4: 5<br>
# Chroma_5: 6

# %% [markdown]
# ## Loading an audio file:
# librosa.load(path, *, sr=22050, mono=True, offset=0.0, duration=None, dtype=<class 'numpy.float32'>, res_type='kaiser_best')
#
# Load an audio file as a floating point time series. Audio will be automatically resampled to the given rate (default sr=22050). To preserve the native sampling rate of the file, use sr=None.
#
# Returns:<br>
# y: np.ndarray [shape=(n,) or (…, n)] audio time series. Multi-channel is supported.<br>
# sr: number > 0 [scalar], sampling rate of y
#
# This returns an audio time series as a numpy array with a default sampling rate(sr) of 22KHZ mono. We can change this behavior by resampling at 44.1KHz.<br>
# librosa.load(audio_data, sr=44100)

# %% [markdown]
# ## Visualizing Audio:
#
# We can plot the audio array using librosa.display.waveplot:
#
#     %matplotlib inline
#     import matplotlib.pyplot as plt
#     import librosa.display
#     plt.figure(figsize=(14, 5))
#     librosa.display.waveshow(x, sr=sr)

# %%
y , sr = librosa.load(data_path["Path"].loc[0])
plt.figure(figsize=(14, 5))
librosa.display.waveshow(x, sr=sr)

# %%
# Trimming leading/lagging silence
y_trimmed, _ = librosa.effects.trim(y, top_db=20)
plt.figure(figsize=(14, 5))
librosa.display.waveshow(y_trimmed, sr=sr)

# %%
pd.Series(y[30000:30500]).plot()
