# %% [markdown]
# # RAVDESS (Ryerson Audio-Visual Database of Emotional Speech and Song)

# %% [markdown]
# Il Ryerson Audio-Visual Database of Emotional Speech and Song (RAVDESS) contiene 7.356 file (dimensione totale: 24,8 GB). Il database contiene 24 attori professionisti (12 femmine, 12 maschi), che vocalizzano due affermazioni lessicalmente abbinate con un accento nordamericano neutro. Il discorso(Speech) include espressioni calme, felici, tristi, arrabbiate, paurose, sorprese e disgustate, e il canto(Song) contiene emozioni calme, felici, tristi, arrabbiate e paurose. Ogni espressione è prodotta a due livelli di intensità emotiva (normale, forte), con un'espressione neutra aggiuntiva. Tutte le condizioni sono disponibili in tre formati di modalità: solo audio (16 bit, 48kHz .wav), audio-video (720p H.264, AAC 48kHz, .mp4) e solo video (senza audio). Nota, non ci sono file di canzoni per Actor_18.

# %% [markdown]
# # Premessa
# Prima di eseguire il seguente codice assicurarsi di aver preparato il dataset utilizzando il file **Dataset Creation.ipynb**.

# %% [markdown]
# # Import moduli

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('dataset.csv', index_col=False)

# %%
dataset.head(6)
# Out:
#                                                 Path Emotions  \
# 0  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 1  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 2  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 3  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...  neutral
# 4  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...     calm
# 5  C:\Users\aleza\Desktop\TesiAZ\Audio_Speech_Act...     calm
#
#   Emotional_intensity                     Statement  Actor Gender  Chroma_1  \
# 0              normal  Kids are talking by the door      1   male  0.758700
# 1              normal  Kids are talking by the door      1   male  0.750273
# 2              normal  Dogs are sitting by the door      1   male  0.774295
# 3              normal  Dogs are sitting by the door      1   male  0.779107
# 4              normal  Kids are talking by the door      1   male  0.698006
# 5              normal  Kids are talking by the door      1   male  0.727278
#
#    Chroma_2  Chroma_3  Chroma_4  ...  SpectralContrast_4  SpectralContrast_5  \
# 0  0.800079  0.787812  0.765054  ...           14.063341           14.782979
# 1  0.784383  0.756965  0.696240  ...           14.882904           15.124753
# 2  0.801573  0.796509  0.787654  ...           14.244311           15.347931
# 3  0.755077  0.747366  0.743538  ...           15.362222           15.282290
# 4  0.760674  0.788748  0.732748  ...           14.200493           15.564639
# 5  0.760926  0.771641  0.786226  ...           13.888503           15.154068
#
#    SpectralContrast_6  SpectralContrast_7  Tonnetz_1  Tonnetz_2  Tonnetz_3  \
# 0           16.763025           46.989867  -0.049029   0.020017  -0.018087
# 1           16.843607           47.182433  -0.083054   0.031095  -0.034040
# 2           16.693162           46.612350  -0.032817   0.011965  -0.007534
# 3           16.066964           46.337370  -0.054700   0.021160   0.001594
# 4           16.215132           46.623707  -0.066973   0.014683   0.017695
# 5           15.790813           46.707163  -0.044697  -0.019892   0.024391
#
#    Tonnetz_4  Tonnetz_5  Tonnetz_6
# 0  -0.064190   0.014618   0.006382
# 1  -0.064046   0.017133   0.001312
# 2   0.000339   0.012825   0.022611
# 3  -0.028112   0.007178   0.009411
# 4  -0.087017   0.018723   0.007281
# 5  -0.053583   0.013991   0.026164
#
# [6 rows x 179 columns]

# %% [markdown]
# # Analisi variabili del datset
# - **Path**: il percorso univoco al file audio (usato per distinguere tutti i file audio);
# - **Emotions**: emozione usata;
# - **Emotional_intensity**: enfasi
# - **Statement**: frase pronunciata;
# - **Actor**: numero attore;
# - **Gender**: sesso attore;
# - **Chroma_x**: funzionalità potenti per l'analisi della musica, infatti le caratteristiche cromatiche sono molto autentiche per catturare le caratteristiche armoniche e melodiche della musica e dello strumento;
# - **MelSpectrogram_x**: input dello spettrogramma mappato direttamente sulla funzione di base Mel, questa rappresentazione dello spettrogramma aumenta la chiarezza uditiva del sistema;
# - **MFCC_x**: è la caratteristica spettrale più utilizzata nel riconoscimento delle emozioni vocali, è una caratteristica vantaggiosa per raccogliere benefici dall'audio grezzo. Funziona anche in modo molto efficace nel rumore; il sistema uditivo umano non è lineare; pertanto, MFCC utilizza la scala Mel;
# - **SpectralContrast_x**: viene stimata l'energia media di un suono e il valore di contrasto elevato è evidente e il valore di contrasto basso corrisponde al rumore a banda larga;
# - **Tonnetz_x**: le caratteristiche di Tonnetz funzionano allo stesso modo come il cromatogramma, è anche correlato all'armonia e alla classe del tono.

# %% [markdown]
# Come si può notare anche dalla cella qui sotto, il numero di variabili è 177 mentre le istanze totali sono 1440.

# %%
dataset.shape
# Out:
# (1440, 179)

# %%
target = "Emotions"

# %%
dataset["Emotions"].value_counts()
# Out:
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: Emotions, dtype: int64

# %%
dataset["Emotions"].value_counts().plot.pie(autopct="%.2f%%");

# %% [markdown]
# Analisi dei dati con distribuzioni, medie, stddev, percentili, numero valori distinti delle feature.

# %%
dataset.iloc[:, :].describe()
# Out:
#              Actor     Chroma_1     Chroma_2     Chroma_3     Chroma_4  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean     12.500000     0.653244     0.655611     0.657969     0.645570
# std       6.924591     0.076868     0.086938     0.090251     0.091643
# min       1.000000     0.367825     0.322613     0.315760     0.329007
# 25%       6.750000     0.603348     0.597126     0.594429     0.580775
# 50%      12.500000     0.661144     0.661716     0.667607     0.660002
# 75%      18.250000     0.709583     0.724050     0.726551     0.714091
# max      24.000000     0.840786     0.867350     0.858982     0.858208
#
#           Chroma_5     Chroma_6     Chroma_7     Chroma_8     Chroma_9  ...  \
# count  1440.000000  1440.000000  1440.000000  1440.000000  1440.000000  ...
# mean      0.617216     0.623934     0.633670     0.656429     0.669104  ...
# std       0.089298     0.083622     0.077928     0.081345     0.079156  ...
# min       0.344647     0.365303     0.316937     0.335627     0.373790  ...
# 25%       0.552444     0.566170     0.582984     0.602942     0.616467  ...
# 50%       0.636207     0.642876     0.647952     0.668434     0.681382  ...
# 75%       0.683862     0.683329     0.688778     0.716020     0.727245  ...
# max       0.821597     0.814194     0.827697     0.842415     0.850827  ...
#
#        SpectralContrast_4  SpectralContrast_5  SpectralContrast_6  \
# count         1440.000000         1440.000000         1440.000000
# mean            15.884615           16.951517           17.368777
# std              1.218528            1.155338            1.298789
# min             12.949554           13.937179           14.760688
# 25%             15.003496           16.110861           16.433930
# 50%             15.735661           16.842360           17.184850
# 75%             16.610332           17.642386           18.090647
# max             20.772887           21.443613           22.920655
#
#        SpectralContrast_7    Tonnetz_1    Tonnetz_2    Tonnetz_3    Tonnetz_4  \
# count         1440.000000  1440.000000  1440.000000  1440.000000  1440.000000
# mean            46.159894    -0.021659     0.014384    -0.013629    -0.010002
# std              2.129640     0.020779     0.018581     0.031369     0.032130
# min             37.094605    -0.117378    -0.082184    -0.145338    -0.150322
# 25%             45.424515    -0.032482     0.002375    -0.034241    -0.029262
# 50%             46.912293    -0.020239     0.013970    -0.015071    -0.008972
# 75%             47.555051    -0.008466     0.026074     0.006226     0.010161
# max             49.987960     0.051258     0.096549     0.097385     0.094855
#
#          Tonnetz_5    Tonnetz_6
# count  1440.000000  1440.000000
# mean      0.006595     0.003162
# std       0.010670     0.010874
# min      -0.040360    -0.033045
# 25%      -0.000402    -0.003947
# 50%       0.006151     0.002737
# 75%       0.012597     0.009428
# max       0.042944     0.045490
#
# [8 rows x 174 columns]

# %%
dataset.pivot_table(index="Path", columns="Emotions", values="MFCC_1").plot.hist(bins=40, stacked=True, figsize=(12, 6));

# %%
dataset.pivot_table(index="Path", columns="Emotional_intensity", values="MFCC_1").plot.hist(bins=40, stacked=True, figsize=(12, 6));

# %% [markdown]
# Procediamo preparando i dati per il nostro modello:
#
# Per prima cosa eliminiamo tutte le colonne che non ci servono(not_features) e tutte le istanze, o righe, dove vi è almeno un valore NaN.
#
# Prima di procedere all'elaborazione dei dati eliminiamo dal dataset le feature non ritenute rilevanti:
# - Path, usato per distinguere i file audio, risulta ridondante in quanto è già presente un indice;
# - Emotional_intensity, per il momento non la prendiamo in considerazione;
# - Statement, il modello deve essere in grado di riconoscere l'emozione indipendentemente dalla frase pronunciata;
# - Gender, lo si può dedurre dal numero dell'attore, uomo se dispari, donna se pari.

# %%
not_features = ["Path", "Emotional_intensity", "Statement", "Gender"]
features_data = dataset.drop(columns=not_features)
features_data
# Out:
#        Emotions  Actor  Chroma_1  Chroma_2  Chroma_3  Chroma_4  Chroma_5  \
# 0       neutral      1  0.758700  0.800079  0.787812  0.765054  0.709206
# 1       neutral      1  0.750273  0.784383  0.756965  0.696240  0.693709
# 2       neutral      1  0.774295  0.801573  0.796509  0.787654  0.728228
# 3       neutral      1  0.779107  0.755077  0.747366  0.743538  0.722850
# 4          calm      1  0.698006  0.760674  0.788748  0.732748  0.676882
# ...         ...    ...       ...       ...       ...       ...       ...
# 1435  surprised     24  0.627197  0.556213  0.542518  0.548569  0.530505
# 1436  surprised     24  0.706613  0.714364  0.660312  0.624816  0.557339
# 1437  surprised     24  0.655388  0.660653  0.591902  0.567328  0.518754
# 1438  surprised     24  0.639784  0.633800  0.618443  0.583396  0.554781
# 1439  surprised     24  0.697430  0.636318  0.615314  0.577386  0.544395
#
#       Chroma_6  Chroma_7  Chroma_8  ...  SpectralContrast_4  \
# 0     0.683323  0.691785  0.736967  ...           14.063341
# 1     0.674186  0.693022  0.730960  ...           14.882904
# 2     0.677872  0.681009  0.726691  ...           14.244311
# 3     0.710327  0.703550  0.765753  ...           15.362222
# 4     0.686023  0.674742  0.711580  ...           14.200493
# ...        ...       ...       ...  ...                 ...
# 1435  0.541727  0.590350  0.589346  ...           16.299321
# 1436  0.514953  0.538145  0.566566  ...           15.608716
# 1437  0.527598  0.543928  0.521588  ...           16.017948
# 1438  0.593419  0.598049  0.566011  ...           16.417546
# 1439  0.577520  0.592597  0.630658  ...           15.863975
#
#       SpectralContrast_5  SpectralContrast_6  SpectralContrast_7  Tonnetz_1  \
# 0              14.782979           16.763025           46.989867  -0.049029
# 1              15.124753           16.843607           47.182433  -0.083054
# 2              15.347931           16.693162           46.612350  -0.032817
# 3              15.282290           16.066964           46.337370  -0.054700
# 4              15.564639           16.215132           46.623707  -0.066973
# ...                  ...                 ...                 ...        ...
# 1435           17.484619           17.199528           43.994441   0.012729
# 1436           16.816470           17.408776           44.370814  -0.025298
# 1437           17.011401           18.315315           43.690512  -0.018453
# 1438           17.718540           17.301842           45.064498  -0.009375
# 1439           16.572856           16.613048           46.041527  -0.028091
#
#       Tonnetz_2  Tonnetz_3  Tonnetz_4  Tonnetz_5  Tonnetz_6
# 0      0.020017  -0.018087  -0.064190   0.014618   0.006382
# 1      0.031095  -0.034040  -0.064046   0.017133   0.001312
# 2      0.011965  -0.007534   0.000339   0.012825   0.022611
# 3      0.021160   0.001594  -0.028112   0.007178   0.009411
# 4      0.014683   0.017695  -0.087017   0.018723   0.007281
# ...         ...        ...        ...        ...        ...
# 1435   0.012887  -0.005402   0.033513   0.001690   0.012433
# 1436   0.015586  -0.003397   0.005630   0.007249   0.001469
# 1437   0.020730  -0.031918   0.011609   0.007734   0.004741
# 1438   0.015481  -0.045660  -0.019431   0.006970  -0.005031
# 1439   0.037146  -0.009946  -0.017167   0.007335   0.004525
#
# [1440 rows x 175 columns]

# %%
features_data.dropna(inplace=True)

# %%
features_data.shape
# Out:
# (1440, 175)

# %% [markdown]
# - Non ci sono valori NaN

# %%
for col in range(len(features_data.columns.to_list())-1):
    separator = "----------------------------------\n"
    print(separator + f'{features_data.columns.to_list()[col].upper()}\n')
    print(features_data.iloc[:, col].value_counts())
# Out:
# ----------------------------------
# EMOTIONS
#
# calm         192
# happy        192
# sad          192
# angry        192
# fearful      192
# disgust      192
# surprised    192
# neutral       96
# Name: Emotions, dtype: int64
# ----------------------------------
# ACTOR
#
# 1     60
# 2     60
# 23    60
# 22    60
# 21    60
# 20    60
# 19    60
# 18    60
# 17    60
# 16    60
# 15    60
# 14    60
# 13    60
# 12    60
# 11    60
# 10    60
# 9     60
# 8     60
# 7     60
# 6     60
# 5     60
# 4     60
# 3     60
# 24    60
# Name: Actor, dtype: int64
# ----------------------------------
# CHROMA_1
#
# 0.786983    2
# 0.758700    1
# 0.732142    1
# 0.749967    1
# 0.747811    1
#            ..
# 0.628574    1
# 0.633678    1
# 0.646831    1
# 0.646644    1
# 0.697430    1
# Name: Chroma_1, Length: 1439, dtype: int64
# ----------------------------------
# CHROMA
Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_1
#
# 23.328702    2
# 19.063653    1
# 16.323802    1
# 20.512642    1
# 21.400666    1
#             ..
# 19.293948    1
# 19.784210    1
# 21.317069    1
# 21.691396    1
# 15.438490    1
# Name: SpectralContrast_1, Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_2
#
# 14.373187    2
# 11.111348    1
# 14.997171    1
# 13.818516    1
# 13.390087    1
#             ..
# 15.330842    1
# 15.370868    1
# 15.811229    1
# 15.209166    1
# 17.200007    1
# Name: SpectralContrast_2, Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_3
#
# 16.736767    2
# 14.831766    1
# 15.302114    1
# 16.848496    1
# 15.955106    1
#             ..
# 17.796972    1
# 16.797362    1
# 16.981851    1
# 16.909327    1
# 17.281574    1
# Name: SpectralContrast_3, Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_4
#
# 15.923136    2
# 14.063341    1
# 15.224832    1
# 15.336716    1
# 14.863054    1
#             ..
# 16.073911    1
# 15.443368    1
# 15.443656    1
# 15.216517    1
# 15.863975    1
# Name: SpectralContrast_4, Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_5
#
# 18.704718    2
# 14.782979    1
# 16.480950    1
# 16.607871    1
# 16.091850    1
#             ..
# 17.253697    1
# 16.801378    1
# 17.277870    1
# 17.595222    1
# 16.572856    1
# Name: SpectralContrast_5, Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_6
#
# 18.384431    2
# 16.763025    1
# 17.359013    1
# 17.100346    1
# 17.013598    1
#             ..
# 17.145884    1
# 16.804705    1
# 17.846442    1
# 17.598034    1
# 16.613048    1
# Name: SpectralContrast_6, Length: 1439, dtype: int64
# ----------------------------------
# SPECTRALCONTRAST_7
#
# 47.390262    2
# 46.989867    1
# 48.389693    1
# 47.374426    1
# 47.495566    1
#             ..
# 46.419898    1
# 46.592853    1
# 47.233983    1
# 46.672087    1
# 46.041527    1
# Name: SpectralContrast_7, Length: 1439, dtype: int64
# ----------------------------------
# TONNETZ_1
#
# -0.025353    2
# -0.049029    1
# -0.014354    1
# -0.075831    1
# -0.024760    1
#             ..
# -0.074825    1
# -0.066593    1
# -0.042413    1
# -0.061241    1
# -0.028091    1
# Name: Tonnetz_1, Length: 1439, dtype: int64
# ----------------------------------
# TONNETZ_2
#
# -0.000931    2
#  0.020017    1
#  0.016565    1
#  0.024501    1
#  0.026036    1
#             ..
#  0.017515    1
#  0.023653    1
#  0.011336    1
#  0.031808    1
#  0.037146    1
# Name: Tonnetz_2, Length: 1439, dtype: int64
# ----------------------------------
# TONNETZ_3
#
# -0.024524    2
# -0.018087    1
# -0.029361    1
# -0.038684    1
# -0.110884    1
#             ..
#  0.040314    1
#  0.022021    1
# -0.020911    1
#  0.006051    1
# -0.009946    1
# Name: Tonnetz_3, Length: 1439, dtype: int64
# ----------------------------------
# TONNETZ_4
#
# -0.065343    2
# -0.064190    1
# -0.002443    1
# -0.078189    1
# -0.114434    1
#             ..
# -0.054627    1
# -0.040337    1
# -0.050251    1
# -0.034039    1
# -0.017167    1
# Name: Tonnetz_4, Length: 1439, dtype: int64
# ----------------------------------
# TONNETZ_5
#
# 0.011465    2
# 0.014618    1
# 0.005381    1
# 0.038722    1
# 0.035953    1
#            ..
# 0.007171    1
# 0.000269    1
# 0.008665    1
# 0.000054    1
# 0.007335    1
# Name: Tonnetz_5, Length: 1439, dtype: int64

# %% [markdown]
# ## Elaborazione dei dati

# %% [markdown]
# In questa fase seguirà un'analisi più approfondita dei dati: standardizzazione, eliminazione feature meno rilevanti con regolarizzazione L1, discretizzazione e binarizzazione delle feature, analisi tramite modelli.
#
# Modello di classificazione lineare con due feature
# Un classificatore a due classi lineare è definito da un iperpiano che separa lo spazio delle variabili in due semispazi
# la classe prevista per un'osservazione (un punto) dipende dal semispazio in cui si trova
# Se consideriamo uno spazio di due variabili (un piano), questo significa in pratica tracciare una retta che separi una classe dall'altra.
#
# Selezioniamo i dati su cui lavorare:
# - la variabile y da predire è la classe: Emotins;
# - le variabili X sono: le varie features (Chroma, MelSpectrogram, MFCC, Spectral_contrast, Tonnetz);

# %% [markdown]
# Suddividiamo i dati in un training set e in un test set nel seguente modo:
# - il training set è composto dai 20 attori rimanenti (10 uomini, 10 donne)
# - il test set è composto da 4 attori(2 uomini, 2 donne)

# %%
import random as r
rn = r.choice(range(1, 24, 2))
print(rn)
# Out:
# 23

# %%
import random

rnd = []
while(len(rnd)!=4):
    for x in range(2):
        rnd.append(random.randrange(2, 25, 2)) #genera i pari
        rnd.append(random.randrange(2, 25, 2) - 1) #genera i dispari
    actor_list = []
    [actor_list.append(x) for x in rnd if x not in actor_list] #controllo non ci siano duplicati

# %%
len(actor_list), actor_list
# Out:
# (4, [16, 19, 12, 5])

# %%
test_set = features_data.loc[features_data['Actor'].isin(actor_list)]

# %%
test_set
# Out:
#        Emotions  Actor  Chroma_1  Chroma_2  Chroma_3  Chroma_4  Chroma_5  \
# 240     neutral      5  0.748571  0.796117  0.796667  0.718178  0.679476
# 241     neutral      5  0.713127  0.700427  0.725807  0.716823  0.702318
# 242     neutral      5  0.673417  0.697459  0.740627  0.703739  0.647055
# 243     neutral      5  0.746489  0.778931  0.765009  0.739975  0.698549
# 244        calm      5  0.708162  0.703103  0.734018  0.695711  0.694369
# ...         ...    ...       ...       ...       ...       ...       ...
# 1135  surprised     19  0.743802  0.776325  0.795410  0.773910  0.733580
# 1136  surprised     19  0.699579  0.674259  0.676244  0.717728  0.663378
# 1137  surprised     19  0.639004  0.636733  0.663980  0.683211  0.639010
# 1138  surprised     19  0.749429  0.727736  0.686227  0.654894  0.623570
# 1139  surprised     19  0.755780  0.730727  0.770210  0.763550  0.736765
#
#       Chroma_6  Chroma_7  Chroma_8  ...  SpectralContrast_4  \
# 240   0.689971  0.651868  0.759501  ...           15.422545
# 241   0.704109  0.672695  0.787390  ...           15.437975
# 242   0.709668  0.709424  0.728550  ...           16.301230
# 243   0.651334  0.680001  0.764371  ...           14.824698
# 244   0.739806  0.726478  0.743586  ...           15.492558
# ...        ...       ...       ...  ...                 ...
# 1135  0.733660  0.737344  0.729643  ...           14.289537
# 1136  0.669386  0.637790  0.658756  ...           16.240844
# 1137  0.638858  0.657849  0.720093  ...           15.490303
# 1138  0.665990  0.658483  0.719631  ...           15.442043
# 1139  0.738221  0.731104  0.751747  ...           14.316943
#
#       SpectralContrast_5  SpectralContrast_6  SpectralContrast_7  Tonnetz_1  \
# 240            17.089461           16.035966           47.727234  -0.023424
# 241            17.784720           16.304775           47.425464  -0.011635
# 242            15.977960           17.629026           48.126774  -0.018337
# 243            15.612123           17.011754           47.673489  -0.015191
# 1435           17.484619           17.199528           43.994441   0.012729
# 1436           16.816470           17.408776           44.370814  -0.025298
# 1437           17.011401           18.315315           43.690512  -0.018453
# 1438           17.718540           17.301842           45.064498  -0.009375
# 1439           16.572856           16.613048           46.041527  -0.028091
#
#       Tonnetz_2  Tonnetz_3  Tonnetz_4  Tonnetz_5  Tonnetz_6
# 0      0.020017  -0.018087  -0.064190   0.014618   0.006382
# 1      0.031095  -0.034040  -0.064046   0.017133   0.001312
# 2      0.011965  -0.007534   0.000339   0.012825   0.022611
# 3      0.021160   0.001594  -0.028112   0.007178   0.009411
# 4      0.014683   0.017695  -0.087017   0.018723   0.007281
# ...         ...        ...        ...        ...        ...
# 1435   0.012887  -0.005402   0.033513   0.001690   0.012433
# 1436   0.015586  -0.003397   0.005630   0.007249   0.001469
# 1437   0.020730  -0.031918   0.011609   0.007734   0.004741
# 1438   0.015481  -0.045660  -0.019431   0.006970  -0.005031
# 1439   0.037146  -0.009946  -0.017167   0.007335   0.004525
#
# [1200 rows x 175 columns]

# %% [markdown]
# **tuning**

# %% [markdown]
# ## Cross validation

# %%
training_actors = training_set['Actor']
training_actors = training_actors.unique()

# %%
training_actors_m = []
training_actors_f = []
for actor in training_actors:
    if (actor%2 == 0):
        training_actors_f.append(actor)
    else:
        training_actors_m.append(actor)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import f1_score
classifier = RandomForestClassifier()

# %% [markdown]
# Cross-fold validation con 10 fold (ciascuono composto da 2 attori, 1 maschio e 1 femmina)

# %%
accuracy = []
f1 = []
for i in range(10):
    m = training_actors_m[i]
    f = training_actors_f[i]
        
    cross_test_set = training_set.loc[training_set['Actor'].isin([m, f])]
    cross_training_set = training_set.drop(cross_test_set.index)
       
    y_train = cross_training_set["Emotions"]
    X2d_train = cross_training_set[dataset.columns[6:]]
    y_test = cross_test_set["Emotions"]
    X2d_test = cross_test_set[dataset.columns[6:]]
    
    # fit the classifier
    classifier.fit(X2d_train, y_train)
    # compute the score and record it
    accuracy.append(classifier.score(X2d_test, y_test))
    y_pred = classifier.predict(X2d_test)
    f1.append(f1_score(y_test, y_pred, average="macro"));

# %%
# Set the figure size
plt.rcParams["figure.figsize"] = [7.50, 3.50]
plt.rcParams["figure.autolayout"] = True

# Pandas dataframe
stats = pd.DataFrame({"Accuracy": accuracy, "F1-Score": f1})

# Plot the dataframe
ax = stats[['Accuracy', 'F1-Score']].plot(kind='box', title='Cross-Validation stats')

# Display the plot
plt.show()

# %%
avg_accuracy = sum(accuracy) / len(accuracy)
avg_accuracy
# Out:
# 0.38250000000000006

# %%
avg_f1 = sum(f1) / len(f1)
avg_f1
# Out:
# 0.3510887560055684

# %% [markdown]
# Ora prepariamo le variabili da utilizzare per addestrare i vari modelli.

# %%
y_train = training_set["Emotions"]
X2d_train = training_set[dataset.columns[6:]]
y_test = test_set["Emotions"]
X2d_test = test_set[dataset.columns[6:]]

# %% [markdown]
# ## Random forest
# E' un algoritmo di tipo bagging, dove vengono creati numerosi alberi decisionali in parallelo, ognuno da un sottoinsieme del dataset di training in generale non disgiunto dagli altri.

# %%
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(5, shuffle=True, random_state=42)

# %%
rfm = RandomForestClassifier(max_samples=0.9, n_estimators=200, max_depth=None, n_jobs=-1, random_state=42)

# %%
rfm.fit(X2d_train, y_train);

# %%
rfm.score(X2d_test, y_test)
# Out:
# 0.4111111111111111

# %%
y_pred = rfm.predict(X2d_test)
f1_score(y_test, y_pred, average="macro")
# Out:
# 0.35385713454252765

# %% [markdown]
# Proviamo con una grid search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import make_scorer

# %%
grid = {
    "max_samples": [0.3, 0.6, 0.9],
    "n_estimators": [200, 400, 600]
}

# %%
gs = GridSearchCV(rfm, grid, cv=skf, scoring=make_scorer(f1_score, average="macro"))

# %%
gs.fit(X2d_train, y_train);

# %%
gs.best_params_
# Out:
# {'max_samples': 0.9, 'n_estimators': 400}

# %%
gscv_results = pd.DataFrame(gs.cv_results_).sort_values("rank_test_score")
gscv_results.head(10)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 7       2.555366      0.285254         0.267879        0.039113
# 6       1.317895      0.051730         0.116680        0.027583
# 8       3.602929      0.206785         0.343879        0.065757
# 4       2.255738      0.094506         0.254471        0.062220
# 5       2.894335      0.273946         0.371975        0.029975
# 3       1.085519      0.045186         0.134561        0.014075
# 2       1.830441      0.157713         0.359699        0.055876
# 1       1.329406      0.134569         0.264426        0.004730
# 0       1.196481      1.243384         0.120341        0.026768
#
#   param_max_samples param_n_estimators  \
# 7               0.9                400
# 6               0.9                200
# 8               0.9                600
# 4               0.6                400
# 5               0.6                600
# 3               0.6                200
# 2               0.3                600
# 1               0.3                400
# 0               0.3                200
#
#                                       params  split0_test_score  \
# 7  {'max_samples': 0.9, 'n_estimators': 400}           0.490337
# 6  {'max_samples': 0.9, 'n_estimators': 200}           0.482569
# 8  {'max_samples': 0.9, 'n_estimators': 600}           0.490597
# 4  {'max_samples': 0.6, 'n_estimators': 400}           0.460849
# 5  {'max_samples': 0.6, 'n_estimators': 600}           0.473526
# 3  {'max_samples': 0.6, 'n_estimators': 200}           0.462323
# 2  {'max_samples': 0.3, 'n_estimators': 600}           0.422585
# 1  {'max_samples': 0.3, 'n_estimators': 400}           0.419709
# 0  {'max_samples': 0.3, 'n_estimators': 200}           0.417457
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 7           0.556433           0.551468           0.499786           0.590943
# 6           0.551216           0.566107           0.512779           0.568356
# 8           0.550624           0.573545           0.482266           0.573592
# 4           0.526769           0.548304           0.496195           0.536641
# 5           0.518812           0.529948           0.498455           0.546486
# 3           0.528648           0.524057           0.472572           0.546651
# 2           0.492987           0.476454           0.434438           0.519111
# 1           0.480252           0.456397           0.439362           0.518134
# 0           0.465785           0.475042           0.420516           0.499958
#
#    mean_test_score  std_test_score  rank_test_score
# 7         0.537793        0.037566                1
# 6         0.536205        0.033403                2
# 8         0.534125        0.039919                3
# 4         0.513752        0.031604                4
# 5         0.513446        0.025342                5
# 3         0.506850        0.033206                6
# 2         0.469115        0.036030                7
# 1         0.462771        0.034099                8
# 0         0.455752        0.032047                9

# %%
model = gs.best_estimator_

# %%
f1_score(y_test, model.predict(X2d_test), average=None)
# Out:
# array([0.57894737, 0.56603774, 0.31428571, 0.38709677, 0.27027027,
#        0.        , 0.31578947, 0.41860465])

# %%
f1_score(y_test, model.predict(X2d_test), average="macro")
# Out:
# 0.35637899848333043

# %% [markdown]
# # ----------------------------------- Codice da corregere ---------------------------------------------

# %% [markdown]
# ## Extreme gradient boosting (XGBoost)
# algoritmo che inizia con un modello a previsone costante, per poi sommare ad ogni iterazione un nuovo modello al precedente; dove ogni albero aggiunto è addestrato dal dataset degli errori residui del precedente.

# %%
#!pip install xgboost==1.1.0
#se già installato de-commenta il comando precedente

# %%
from xgboost import XGBClassifier

# %%
xgbm = XGBClassifier(objective='binary:logistic', reg_alpha=0.5, reg_lambda=1.0, max_samples=0.9, n_estimators=200, random_state=42)

# %%
grid = {
    "max_samples": [0.3, 0.6, 0.9],
    "n_estimators": [200, 400, 600],
    "reg_alpha": [0.5, 1, 1.5],
    "reg_lambda": [0.5, 1, 1.5]
}

# %%
gs = GridSearchCV(xgbm, grid, cv=skf, scoring=make_scorer(f1_score, average="macro"))

# %%
gs.fit(X2d_train, y_train);
# Out:
# [11:44:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:10] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:44:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:05] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:45:56] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:10] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [11:46:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:46:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:28] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:47:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:05] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:48:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:49:06] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:49:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [11:49:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:49:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:49:37] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:49:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:49:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:50:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:50:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:50:29] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:50:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:50:51] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:51:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:51:13] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:51:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:51:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:51:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:51:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:52:10] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:52:20] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:52:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:52:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:52:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:53:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [11:53:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:53:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:53:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:53:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:53:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:54:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:54:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:54:30] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:54:42] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:54:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:55:04] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:55:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:55:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:55:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:55:43] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:55:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:56:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:56:14] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:56:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:56:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:56:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:56:59] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [11:57:10] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:57:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:57:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:57:46] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:58:01] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:58:15] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:58:30] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:58:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:58:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:59:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:59:26] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:59:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [11:59:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:00:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:00:23] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:00:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:00:53] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:01:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:01:22] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:01:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:01:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:02:08] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:02:25] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:02:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:02:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:03:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:03:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:03:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:03:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:04:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:04:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:04:30] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:04:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:04:57] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:05:11] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:05:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
# ...
#
#
# [12:46:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:05] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:19] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:34] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:47:48] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:48:47] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:49:02] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:16] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:30] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:44] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:49:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:41] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:50:55] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:24] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:38] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:51:52] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:06] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:36] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:52:50] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:04] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:18] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:45] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:53:58] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# [12:54:13] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:54:27] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:54:40] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:54:54] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:55:07] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:55:21] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:55:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:55:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:56:03] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [12:56:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { max_samples } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
gs.best_params_
# Out:
# {'max_samples': 0.3, 'n_estimators': 200, 'reg_alpha': 0.5, 'reg_lambda': 0.5}

# %%
model = gs.best_estimator_

# %%
f1_score(y_test, model.predict(X2d_test), average="macro")
# Out:
# 0.3945662525786072

# %% [markdown]
# ## Gradient boosting
# Un insieme additivo di un modello base il cui errore viene corretto in successive iterazioni (o fasi) mediante l'aggiunta di alberi di regressione che correggono i residui (l'errore della fase precedente).

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm = GradientBoostingClassifier(n_estimators=200, max_features=2, max_depth=None, random_state=42)

# %%
grid = {
    "n_estimators": [200, 400, 600],
    "max_features": [2, 3, 4]
}

# %%
gs = GridSearchCV(gbm, grid, cv=skf, scoring=make_scorer(f1_score, average="macro"))

# %%
gs.fit(X2d_train, y_train);

# %%
gs.best_params_
# Out:
# {'max_features': 4, 'n_estimators': 200}

# %%
model = gs.best_estimator_

# %%
f1_score(y_test, model.predict(X2d_test), average="macro")
# Out:
# 0.33918077547512215

# %% [markdown]
# ## Regressione Logistica
# Agoritmo grazie al quale possiamo introdurre la regolarizzazione al fine di verificare quali siano le features più e meno significative. Qui in seguito è riportata una breve descrizione di questo algoritmo presa dal laboratorio sulla classificazione:
#
# La regressione logistica è un modello di classificazione binaria basato sulla regressione lineare
# Sia data una variabile y pari a 1 per gli esempi di una classe (positiva) e -1 per quelli dell'altra (negativa), si minimizza la funzione
#
# <math xmlns="http://www.w3.org/1998/Math/MathML" display="block">
#   <munderover>
#     <mo data-mjx-texclass="OP">&#x2211;</mo>
#     <mrow data-mjx-texclass="ORD">
#       <mi>i</mi>
#       <mo>=</mo>
#       <mn>1</mn>
#     </mrow>
#     <mi>n</mi>
#   </munderover>
#   <mi>log</mi>
#   <mo data-mjx-texclass="NONE">&#x2061;</mo>
#   <mo stretchy="false">(</mo>
#   <mi>exp</mi>
#   <mo data-mjx-texclass="NONE">&#x2061;</mo>
#   <mo stretchy="false">(</mo>
#   <mo>&#x2212;</mo>
#   <msub>
#     <mi>y</mi>
#     <mi>i</mi>
#   </msub>
#   <mo stretchy="false">(</mo>
#   <msubsup>
#     <mi>X</mi>
#     <mi>i</mi>
#     <mi>T</mi>
#   </msubsup>
#   <mi>w</mi>
#   <mo>+</mo>
#   <mi>c</mi>
#   <mo stretchy="false">)</mo>
#   <mo stretchy="false">)</mo>
#   <mo>+</mo>
#   <mn>1</mn>
#   <mo stretchy="false">)</mo>
# </math

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

model = Pipeline([
    ("poly", PolynomialFeatures(degree=1, include_bias=False)),
    ("logregr", LogisticRegression(solver="saga", random_state=42, C=0.001, class_weight={'neutral': 2, 'calm': 1, 'happy': 1, 'sad': 1, 'angry': 1, 'fearful': 1, 'disgust': 1, 'surprised': 1}))
])

# %% [markdown]
# - solver indica quale implementazione usare tra diverse disponibili per il training, "saga" è l'unica a supportare tutte le opzioni per la regolarizzazione.
# - class_weight indica il peso da dare a ciascuna classe in fase di training, nel nostro caso sappiamo dall'analisi sui dati che "neutral" copre il 6,67% delle istanze mentre ciascuna delle altre emozioni il 13,33%. Proviamo quindi a pesare 1:2 le due classi.
# - Qui sotto invece utilizziamo il training set ed il validation set creati per il modello precedente, in modo che vengano sfruttati anche in questo caso la standardizzazione ed il OneHotEncoding.

# %%
model.fit(X2d_train, y_train);
# Out:
# C:\Users\aleza\anaconda3\lib\site-packages\sklearn\linear_model\_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(

# %% [markdown]
# 132    2.096157e-05
# 133    2.407761e-05
# 134    2.551096e-05
# 135    2.150835e-05
# 136    1.318792e-05
# 137    3.919562e-06
# 138    3.603202e-07
# 139    5.100314e-09
# 140    7.739768e-03
# 141   -5.115406e-03
# 142   -1.572520e-02
# 143    3.520066e-02
# 144   -4.638923e-02
# 145   -1.488281e-02
# 146    6.157650e-02
# 147    2.218513e-02
# 148   -1.710594e-02
# 149   -5.395928e-03
# 150   -2.307657e-03
# 151    1.034341e-03
# 152    2.022758e-03
# 153   -2.263443e-02
# 154   -2.143204e-02
# 155   -6.093467e-03
# 156   -1.318432e-02
# 157   -1.343613e-02
# 158   -2.317980e-02
# 159   -1.561418e-03
# 160    2.049252e-02
# 161    1.253689e-02
# 162    1.716440e-02
# 163    1.837635e-02
# 164    1.803416e-02
# 165    2.437141e-02
# 166    4.963978e-02
# 167   -3.609760e-05
# 168    3.494080e-05
# 169    4.350078e-05
# 170   -7.000763e-05
# 171    1.517515e-05
# 172    1.138616e-05
# 173    1.554278e-03
# dtype: float64

# %%
pd.reset_option("display.max_rows")

# %%
model.score(X2d_test, y_test)
# Out:
# 0.42916666666666664

# %%
y_pred = model.predict(X2d_test)

# %%
f1_score(y_test, y_pred, average=None)
# Out:
# array([0.65454545, 0.55421687, 0.40384615, 0.49180328, 0.29166667,
#        0.33333333, 0.04878049, 0.47826087])

# %%
f1_score(y_test, y_pred, average="macro")
# Out:
# 0.4070566389900135

# %% [markdown]
# ## Multi-layer Perceptron classifier (MLP)
# Questo modello ottimizza la funzione di perdita logaritmica utilizzando LBFGS o la discesa del gradiente stocastico; è una rete neurale artificiale feedforward che genera un insieme di output da un insieme di input. Un MLP è caratterizzato da diversi livelli di nodi di input collegati come un grafico diretto tra i livelli di input e output. MLP utilizza la retropropagazione per addestrare la rete.

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp = MLPClassifier(random_state=42, max_iter=300)

# %%
mlp.fit(X2d_train, y_train);

# %%
mlp.score(X2d_test, y_test)
# Out:
# 0.4666666666666667

# %%
y_pred = mlp.predict(X2d_test)

# %%
f1_score(y_test, y_pred, average=None)
# Out:
# array([0.71641791, 0.3655914 , 0.51515152, 0.44      , 0.35087719,
#        0.4516129 , 0.19512195, 0.58666667])

# %%
f1_score(y_test, y_pred, average="macro")
# Out:
# 0.45267994219289753

# %% [markdown]
# ## C-Support Vector Classification (SVC)
# Un algoritmo di apprendimento automatico supervisionato tipicamente utilizzato per attività di classificazione. SVC funziona mappando i punti dati in uno spazio ad alta dimensione e quindi trovando l'iperpiano ottimale che divide i dati in due classi.
# Il supporto multiclasse è gestito secondo uno schema one-vs-one.

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler

# %%
model = Pipeline([
    ('standardscaler', StandardScaler()),
                ('svc', SVC(gamma='auto'))
])

# %%
model.fit(X2d_train, y_train);

# %%
model.score(X2d_test, y_test)
# Out:
# 0.425

# %%
y_pred = model.predict(X2d_test)

# %%
f1_score(y_test, y_pred, average=None)
# Out:
# array([0.53571429, 0.58139535, 0.44036697, 0.34042553, 0.25      ,
#        0.        , 0.24615385, 0.55737705])

# %%
f1_score(y_test, y_pred, average="macro")
# Out:
# 0.36892912928470334
